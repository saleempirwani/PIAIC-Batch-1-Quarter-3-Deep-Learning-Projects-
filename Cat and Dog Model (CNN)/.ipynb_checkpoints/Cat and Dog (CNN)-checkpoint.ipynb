# %% [markdown]
# ## Cat and Dog (CNN) Model
# ***Created by: Engg. Muhammad Saleem Raza***

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dense, Flatten, Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img_gen = ImageDataGenerator(rotation_range=30,
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            rescale=1/255,
                            shear_range=0.2,
                            zoom_range=0.2,
                            horizontal_flip=True,
                            fill_mode='nearest')

# %%
img_gen.flow_from_directory('cat_dog/train') # change path
# Out:
# Found 8005 images belonging to 2 classes.

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape=(150,150,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), input_shape=(150,150,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64, kernel_size=(3,3), input_shape=(150,150,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(128))
model.add(Activation('relu'))

model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18496)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               2367616
# _________________________________________________________________
# activation (Activation)      (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 2,424,065
# Trainable params: 2,424,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16
input_shape = (150, 150, 3)

# %%
train_image_gen = img_gen.flow_from_directory('cat_dog/train/', 
                                             target_size=input_shape[:2],
                                             batch_size=batch_size,
                                             class_mode='binary')
# Out:
# Found 8005 images belonging to 2 classes.

# %%
test_image_gen = img_gen.flow_from_directory('cat_dog/test/', 
                                             target_size=input_shape[:2],
                                             batch_size=batch_size,
                                             class_mode='binary')
# Out:
# Found 2023 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %%
result = model.fit_generator(train_image_gen, epochs=100, steps_per_epoch=150, 
                            validation_data=test_image_gen, validation_steps=12, )
# Out:
# Epoch 1/100
# 150/150 [==============================] - 161s 1s/step - loss: 0.6935 - accuracy: 0.5170 - val_loss: 0.6760 - val_accuracy: 0.5625
# Epoch 2/100
# 150/150 [==============================] - 157s 1s/step - loss: 0.6821 - accuracy: 0.5771 - val_loss: 0.6508 - val_accuracy: 0.6354
# Epoch 3/100
# 150/150 [==============================] - 152s 1s/step - loss: 0.6777 - accuracy: 0.5875 - val_loss: 0.7063 - val_accuracy: 0.5312
# Epoch 4/100
# 150/150 [==============================] - 147s 980ms/step - loss: 0.6749 - accuracy: 0.6046 - val_loss: 0.6662 - val_accuracy: 0.6771
# Epoch 5/100
# 150/150 [==============================] - 127s 846ms/step - loss: 0.6541 - accuracy: 0.6316 - val_loss: 0.7188 - val_accuracy: 0.5625
# Epoch 6/100
# 150/150 [==============================] - 125s 836ms/step - loss: 0.6481 - accuracy: 0.6379 - val_loss: 0.6898 - val_accuracy: 0.6146
# Epoch 7/100
# 150/150 [==============================] - 125s 836ms/step - loss: 0.6300 - accuracy: 0.6538 - val_loss: 0.6380 - val_accuracy: 0.6615
# Epoch 8/100
# Epoch 67/100
# 150/150 [==============================] - 125s 836ms/step - loss: 0.3956 - accuracy: 0.8163 - val_loss: 0.3614 - val_accuracy: 0.8490
# Epoch 68/100
# 150/150 [==============================] - 125s 835ms/step - loss: 0.3895 - accuracy: 0.8208 - val_loss: 0.4887 - val_accuracy: 0.7552
# Epoch 69/100
# 150/150 [==============================] - 127s 849ms/step - loss: 0.4070 - accuracy: 0.8158 - val_loss: 0.3992 - val_accuracy: 0.8229
# Epoch 70/100
# 150/150 [==============================] - 126s 843ms/step - loss: 0.3916 - accuracy: 0.8167 - val_loss: 0.3445 - val_accuracy: 0.8542
# Epoch 71/100
# 150/150 [==============================] - 126s 841ms/step - loss: 0.4103 - accuracy: 0.8163 - val_loss: 0.4319 - val_accuracy: 0.8021
# Epoch 72/100
# 150/150 [==============================] - 126s 837ms/step - loss: 0.3851 - accuracy: 0.8255 - val_loss: 0.3625 - val_accuracy: 0.8385
# Epoch 73/100
# 150/150 [==============================] - 126s 840ms/step - loss: 0.4104 - accuracy: 0.8208 - val_loss: 0.3760 - val_accuracy: 0.8542
# Epoch 74/100
# 150/150 [==============================] - 126s 838ms/step - loss: 0.3975 - accuracy: 0.8175 - val_loss: 0.4096 - val_accuracy: 0.8177
# Epoch 75/100
# 150/150 [==============================] - 127s 844ms/step - loss: 0.3988 - accuracy: 0.8213 - val_loss: 0.3789 - val_accuracy: 0.8177
# Epoch 76/100
# 150/150 [==============================] - 126s 840ms/step - loss: 0.3969 - accuracy: 0.8096 - val_loss: 0.4135 - val_accuracy: 0.8385
# Epoch 77/100
# 150/150 [==============================] - 126s 841ms/step - loss: 0.3856 - accuracy: 0.8238 - val_loss: 0.4091 - val_accuracy: 0.8438
# Epoch 78/100
# 150/150 [==============================] - 126s 841ms/step - loss: 0.3879 - accuracy: 0.8388 - val_loss: 0.4154 - val_accuracy: 0.8333
# Epoch 79/100
# 150/150 [==============================] - 126s 839ms/step - loss: 0.3714 - accuracy: 0.8334 - val_loss: 0.4270 - val_accuracy: 0.8229
# Epoch 80/100
# 150/150 [==============================] - 126s 842ms/step - loss: 0.3909 - accuracy: 0.8321 - val_loss: 0.3625 - val_accuracy: 0.8438
# Epoch 81/100
# 150/150 [==============================] - 126s 842ms/step - loss: 0.3838 - accuracy: 0.8304 - val_loss: 0.3981 - val_accuracy: 0.8229
# Epoch 82/100
# 150/150 [==============================] - 127s 843ms/step - loss: 0.3935 - accuracy: 0.8363 - val_loss: 0.3321 - val_accuracy: 0.8490
# Epoch 83/100
# 150/150 [==============================] - 126s 838ms/step - loss: 0.3874 - accuracy: 0.8384 - val_loss: 0.3788 - val_accuracy: 0.8177
# Epoch 84/100
# 150/150 [==============================] - 126s 842ms/step - loss: 0.3735 - accuracy: 0.8383 - val_loss: 0.4377 - val_accuracy: 0.8281
# Epoch 85/100
# 150/150 [==============================] - 126s 839ms/step - loss: 0.3707 - accuracy: 0.8418 - val_loss: 0.4087 - val_accuracy: 0.8490
# Epoch 86/100
# 150/150 [==============================] - 126s 842ms/step - loss: 0.3630 - accuracy: 0.8388 - val_loss: 0.4054 - val_accuracy: 0.8385
# Epoch 87/100
# 150/150 [==============================] - 126s 842ms/step - loss: 0.3785 - accuracy: 0.8342 - val_loss: 0.3127 - val_accuracy: 0.8438
# Epoch 88/100
# 150/150 [==============================] - 126s 843ms/step - loss: 0.3676 - accuracy: 0.8346 - val_loss: 0.4374 - val_accuracy: 0.8125
# Epoch 89/100
# 150/150 [==============================] - 126s 841ms/step - loss: 0.3819 - accuracy: 0.8358 - val_loss: 0.3925 - val_accuracy: 0.8490
# Epoch 90/100
# 150/150 [==============================] - 127s 844ms/step - loss: 0.3781 - accuracy: 0.8325 - val_loss: 0.3886 - val_accuracy: 0.7917
# Epoch 91/100
# 150/150 [==============================] - 126s 838ms/step - loss: 0.3936 - accuracy: 0.8305 - val_loss: 0.3754 - val_accuracy: 0.8542
# Epoch 92/100
# 150/150 [==============================] - 126s 843ms/step - loss: 0.3678 - accuracy: 0.8396 - val_loss: 0.3818 - val_accuracy: 0.8646
# Epoch 93/100
# 150/150 [==============================] - 126s 842ms/step - loss: 0.3583 - accuracy: 0.8442 - val_loss: 0.4257 - val_accuracy: 0.8021
# Epoch 94/100
# 150/150 [==============================] - 126s 839ms/step - loss: 0.3774 - accuracy: 0.8296 - val_loss: 0.4172 - val_accuracy: 0.8385
# Epoch 95/100
# 150/150 [==============================] - 127s 845ms/step - loss: 0.3454 - accuracy: 0.8487 - val_loss: 0.3879 - val_accuracy: 0.8177
# Epoch 96/100
# 150/150 [==============================] - 126s 840ms/step - loss: 0.3676 - accuracy: 0.8392 - val_loss: 0.3626 - val_accuracy: 0.8229
# Epoch 97/100
# 150/150 [==============================] - 126s 840ms/step - loss: 0.3515 - accuracy: 0.8539 - val_loss: 0.3750 - val_accuracy: 0.8646
# Epoch 98/100
# 150/150 [==============================] - 128s 854ms/step - loss: 0.3561 - accuracy: 0.8409 - val_loss: 0.3865 - val_accuracy: 0.8385
# Epoch 99/100
# 150/150 [==============================] - 126s 842ms/step - loss: 0.3587 - accuracy: 0.8413 - val_loss: 0.3769 - val_accuracy: 0.8229
# Epoch 100/100
# 150/150 [==============================] - 126s 843ms/step - loss: 0.3730 - accuracy: 0.8342 - val_loss: 0.3698 - val_accuracy: 0.8281

# %%
train_accuracy = result.history['accuracy']
val_accuracy = result.history['val_accuracy']

# %%
plt.plot(train_accuracy, color='b', label='Training Acc')
plt.plot(val_accuracy, color='g', label='Validation acc')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()

# %%
train_image_gen.class_indices

# %%
model.save('cat_dog_trained_model.h5')

# %% [markdown]
# ### Loading model

# %%
m = load_model('cat_dog_trained_model.h5')

# %% [markdown]
# ### Prediction on new Images

# %%
path = 'images/cat.jpg'

img = image.load_img(path, target_size=(150,150)) 
img = image.img_to_array(img)
img = img / 255

plt.imshow(img)

img = np.expand_dims(img, axis=0)

if m.predict_classes(img)[0][0] == 0:
    print('Cat')
else:
    print('Dog')
# Out:
# Cat
